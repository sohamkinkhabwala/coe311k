# %%
import numpy as np

def lu_decomposition(A):
    n = len(A)
    L = np.eye(n)  # Initialize L as an identity matrix
    U = np.array(A, dtype=float)  # Copy of A to avoid
    factor = 0
    # modifying the original matrix
    
    for i in range(n):
        # Eliminate elements below the pivot (U[i, i])
        for j in range(i+1, n):
            if U[i, i] == 0:
                raise ValueError("Zero pivot encountered. LU decomposition cannot proceed.")
                factor = U[j, i] / U[i, i]  # Multiplier for row
     # operation
            L[j, i] = factor  # Store multiplier in L
            
            # Update the rows of U
            for k in range(i, n):
                U[j, k] -= factor * U[i, k]
    
    return L, U

# %%
# Example usage
A = np.array([[2, 3, 1],
              [4, 7, -1],
              [-2, 1, 2]])

L, U = lu_decomposition(A)

print("Matrix A:\n", A)
print("Lower Triangular Matrix L:\n", L)
print("Upper Triangular Matrix U:\n", U)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 6
#       1 # Example usage
#       2 A = np.array([[2, 3, 1],
#       3               [4, 7, -1],
#       4               [-2, 1, 2]])
# ----> 6 L, U = lu_decomposition(A)
#       8 print("Matrix A:\n", A)
#       9 print("Lower Triangular Matrix L:\n", L)
#
# Cell In[7], line 17, in lu_decomposition(A)
#      15            factor = U[j, i] / U[i, i]  # Multiplier for row
#      16 # operation
# ---> 17        L[j, i] = factor  # Store multiplier in L
#      19        # Update the rows of U
#      20        for k in range(i, n):
#
# UnboundLocalError: cannot access local variable 'factor' where it is not associated with a value
