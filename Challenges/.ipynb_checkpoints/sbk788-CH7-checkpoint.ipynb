# %%
import numpy as np
import time

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        if np.linalg.norm(x_new - x) < tol:
            return x, k
        x = x_new
    return x, max_iterations

def run_challenge(A, b, tol, max_iterations):
    A = np.array(A, dtype=float)
    b = np.array(b, dtype=float)
    x0 = np.zeros(len(b))

    start = time.perf_counter()
    x_jac, iter_jac = jacobi(A, b, x0, tol, max_iterations)
    time_jac = time.perf_counter() - start

    start = time.perf_counter()
    x_gs, iter_gs = gauss_seidel(A, b, x0, tol, max_iterations)
    time_gs = time.perf_counter() - start

    print('Jacobi:')
    print('  Iterations:', iter_jac + 1 if iter_jac < max_iterations else max_iterations)
    print('  Time:', round(time_jac, 6), 's')
    print('  Solution:', np.round(x_jac, 6).tolist())

    print('Gauss-Seidel:')
    print('  Iterations:', iter_gs + 1 if iter_gs < max_iterations else max_iterations)
    print('  Time:', round(time_gs, 6), 's')
    print('  Solution:', np.round(x_gs, 6).tolist())

# %%
# Part 1
A = np.array([
    [0.582745, 0.48,      0.10,     0.,       0.      ],
    [0.48,     1.044129,  0.46,     0.10,     0.      ],
    [0.10,     0.46,      1.10431,  0.44,     0.10    ],
    [0.,       0.10,      0.44,     0.963889, 0.42    ],
    [0.,       0.,        0.10,     0.42,     0.522565],
], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431, 1.923889, 1.042565], dtype=float)
run_challenge(A, b, 10e-6, 100)
# Out:
# Jacobi:
#   Iterations: 100
#   Time: 0.006402 s
#   Solution: [0.342539, 0.342198, 0.342152, 0.342334, 0.342779]
# Gauss-Seidel:
#   Iterations: 18
#   Time: 0.000883 s
#   Solution: [0.999988, 1.000008, 0.999997, 1.0, 1.0]

# %%
# Part 2
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1])
run_challenge(A, b, 10e-6, 100)
# Out:
# Jacobi:
#   Iterations: 100
#   Time: 0.001664 s
#   Solution: [0.004987, 0.0]
# Gauss-Seidel:
#   Iterations: 2
#   Time: 0.000761 s
#   Solution: [1.0, 0.0]

# %%
# Part 3
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1.0001])
run_challenge(A, b, 10e-6, 100)
# Out:
# Jacobi:
#   Iterations: 100
#   Time: 0.001813 s
#   Solution: [0.0, 0.004987]
# Gauss-Seidel:
#   Iterations: 100
#   Time: 0.002904 s
#   Solution: [0.990149, 0.00995]
