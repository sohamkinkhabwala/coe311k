# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(0, 2 * np.pi, 50)
y_sin = np.sin(x)
y_cos = np.cos(x)
a = np.random.rand(1000)
b = np.random.rand(1000)

plt.subplot(2, 2, 1)
plt.plot(x, y_sin, 'r-o', label='Sin(x)')
plt.plot(x, y_cos, 'b--', label='Cos(x)')
plt.title('Sin & Cos')
plt.legend()

plt.subplot(2, 2, 2)
size = np.random.rand(1000) * 50
color = np.random.rand(1000)
plt.scatter(a, b, size, color)
plt.title('Scatter Plot')

plt.subplot(2, 2, 3)
plt.hist(a, 30, color='blue', edgecolor='black')
plt.title('Histogram')

ax = plt.subplot(2, 2, 4, projection='3d')
X, Y = np.meshgrid(np.linspace(-5, 5, 50), np.linspace(-5, 5, 50))
Z = X**2 + Y**2
ax.contour3D(X, Y, Z, 50, cmap='hot')
ax.set_title('x^2 + y^2 Mesh')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 24
#      21 plt.title('Scatter Plot')
#      23 plt.subplot(2, 2, 3)
# ---> 24 plt.hist(a, 30, color='blue', edge='black')
#      25 plt.title('Histogram')
#      27 ax = plt.subplot(2, 2, 4, projection='3d')
#
# File /opt/conda/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.13/site-packages/matplotlib/pyplot.py:3478, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3453 @_copy_docstring_and_deprecators(Axes.hist)
#    3454 def hist(
#    3455     x: ArrayLike | Sequence[ArrayLike],
#    (...)   3476     BarContainer | Polygon | list[BarContainer | Polygon],
#    3477 ]:
# -> 3478     return gca().hist(
#    3479         x,
#    3480         bins=bins,
#    3481         range=range,
#    3482         density=density,
#    3483         weights=weights,
#    3484         cumulative=cumulative,
#    3485         bottom=bottom,
#    3486         histtype=histtype,
#    3487         align=align,
#    3488         orientation=orientation,
#    3489         rwidth=rwidth,
#    3490         log=log,
#    3491         color=color,
#    3492         label=label,
#    3493         stacked=stacked,
#    3494         **({"data": data} if data is not None else {}),
#    3495         **kwargs,
#    3496     )
#
# File /opt/conda/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.13/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File /opt/conda/lib/python3.13/site-packages/matplotlib/axes/_axes.py:7316, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7308 p = patch[0]
#    7309 kwargs.update({
#    7310     'hatch': next(hatches),
#    7311     'linewidth': next(linewidths),
#    (...)   7314     'facecolor': next(facecolors),
#    7315 })
# -> 7316 p._internal_update(kwargs)
#    7317 if lbl is not None:
#    7318     p.set_label(lbl)
#
# File /opt/conda/lib/python3.13/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File /opt/conda/lib/python3.13/site-packages/matplotlib/artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'edge'
